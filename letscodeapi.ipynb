# %%
#dados para completar sua funcionalidade, mas vc não tem acesso direito. Comunicacao com um banco de dados, para utilizar, modificar ou consumir.
#rotas para fazer requisicao para recuperar ou alterar dado
#api sistema online, mas resposta é jason. (JAVASCRIPT)
#utiliza request como biblioteca

# !pip install requests

# %%
import requests

# %%
url = 'https://api.exchangerate-api.com/v6/latest'

req = requests.get(url)

print(req.status_code)
# Out:
# 200

# %%
#recuperar dados da requisiçao

dados = req.json() #retorna um dicionario

print(dados) #base_code moeda base e rates a conversao do basecode para outras moedas
# Out:
# {'result': 'success', 'provider': 'https://www.exchangerate-api.com', 'documentation': 'https://www.exchangerate-api.com/docs/free', 'terms_of_use': 'https://www.exchangerate-api.com/terms', 'time_last_update_unix': 1662940952, 'time_last_update_utc': 'Mon, 12 Sep 2022 00:02:32 +0000', 'time_next_update_unix': 1663028702, 'time_next_update_utc': 'Tue, 13 Sep 2022 00:25:02 +0000', 'time_eol_unix': 0, 'base_code': 'USD', 'rates': {'USD': 1, 'AED': 3.6725, 'AFN': 88.49357, 'ALL': 118.020028, 'AMD': 404.871282, 'ANG': 1.79, 'AOA': 428.267336, 'ARS': 141.769684, 'AUD': 1.46079, 'AWG': 1.79, 'AZN': 1.707599, 'BAM': 1.94448, 'BBD': 2, 'BDT': 94.293842, 'BGN': 1.944513, 'BHD': 0.376, 'BIF': 2040.88038, 'BMD': 1, 'BND': 1.397197, 'BOB': 6.930272, 'BRL': 5.189782, 'BSD': 1, 'BTN': 79.685675, 'BWP': 13.023338, 'BYN': 2.621396, 'BZD': 2, 'CAD': 1.301472, 'CDF': 2018.535283, 'CHF': 0.959845, 'CLP': 885.527374, 'CNY': 6.938648, 'COP': 4428.002729, 'CRC': 657.335304, 'CUP': 24, 'CVE': 109.62513, 'C
# ...

# %%
valor_reais = float(input('informe o valor em R$ a ser convertido\n'))
cotacao = dados ['rates']['BRL']
print(f'R${valor_reais} em dolar valem {(valor_reais / cotacao)} ')
# Out:
# informe o valor em R$ a ser convertido
#  1000
# R$1000.0 em dolar valem 192.68632092831643

# %%
#projeto final

import requests as r

# %%
url = 'https://api.covid19api.com/dayone/country/brazil'
resp = r.get(url)

# %%
resp.status_code
# Out:
# 200

# %%
raw_data = resp.json()

# %%
raw_data[0]
# Out:
# {'ID': '62e4fb7a-73b2-4c60-8cd1-e7f9d280cea3',
#  'Country': 'Brazil',
#  'CountryCode': 'BR',
#  'Province': '',
#  'City': '',
#  'CityCode': '',
#  'Lat': '-14.24',
#  'Lon': '-51.93',
#  'Confirmed': 893322,
#  'Deaths': 44190,
#  'Recovered': 477709,
#  'Active': 366603,
#  'Date': '2020-06-15T00:00:00Z'}

# %%
final_data = []
for obs in raw_data:
    final_data.append([obs['Confirmed'], obs['Deaths'], obs ['Recovered'], obs['Active'], obs ['Date']])

# %%
final_data.insert(0,['confirmados', 'óbitos', 'Recuperados', 'ativos', 'data'])
final_data
# Out:
# [['confirmados', 'óbitos', 'Recuperados', 'ativos', 'data'],
#  ['confirmados', 'óbitos', 'Recuperados', 'ativos', 'data'],
#  ['confirmados', 'óbitos', 'Recuperados', 'ativos', 'data'],
#  [1, 0, 0, 1, '2020-02-26'],
#  [1, 0, 0, 1, '2020-02-27'],
#  [1, 0, 0, 1, '2020-02-28'],
#  [2, 0, 0, 2, '2020-02-29'],
#  [2, 0, 0, 2, '2020-03-01'],
#  [2, 0, 0, 2, '2020-03-02'],
#  [2, 0, 0, 2, '2020-03-03'],
#  [4, 0, 0, 4, '2020-03-04'],
#  [4, 0, 0, 4, '2020-03-05'],
#  [13, 0, 0, 13, '2020-03-06'],
#  [13, 0, 0, 13, '2020-03-07'],
#  [20, 0, 0, 20, '2020-03-08'],
#  [25, 0, 0, 25, '2020-03-09'],
#  [31, 0, 0, 31, '2020-03-10'],
#  [38, 0, 0, 38, '2020-03-11'],
#  [52, 0, 0, 52, '2020-03-12'],
#  [151, 0, 0, 151, '2020-03-13'],
#  [151, 0, 0, 151, '2020-03-14'],
#  [162, 0, 0, 162, '2020-03-15'],
#  [200, 0, 1, 199, '2020-03-16'],
#  [321, 1, 2, 318, '2020-03-17'],
#  [372, 3, 2, 367, '2020-03-18'],
#  [621, 6, 2, 613, '2020-03-19'],
#  [793, 11, 2, 780, '2020-03-20'],
# ...

# %%
CONFIRMADOS = 0
OBITOS = 1
RECUPERADOS = 2
ATIVOS = 3
DATA = 4

# %%
for i in range(1,len(final_data)):
    final_data[i][DATA] = final_data[i][DATA][:10] #dATA VAIO APARECER APENAS OS 9 PRIMEIROS CARACTERES

# %%
final_data
# Out:
# [[1, 0, 0, 1, '2020-02-26T00:00:00Z'],
#  [1, 0, 0, 1, '2020-02-27'],
#  [1, 0, 0, 1, '2020-02-28'],
#  [2, 0, 0, 2, '2020-02-29'],
#  [2, 0, 0, 2, '2020-03-01'],
#  [2, 0, 0, 2, '2020-03-02'],
#  [2, 0, 0, 2, '2020-03-03'],
#  [4, 0, 0, 4, '2020-03-04'],
#  [4, 0, 0, 4, '2020-03-05'],
#  [13, 0, 0, 13, '2020-03-06'],
#  [13, 0, 0, 13, '2020-03-07'],
#  [20, 0, 0, 20, '2020-03-08'],
#  [25, 0, 0, 25, '2020-03-09'],
#  [31, 0, 0, 31, '2020-03-10'],
#  [38, 0, 0, 38, '2020-03-11'],
#  [52, 0, 0, 52, '2020-03-12'],
#  [151, 0, 0, 151, '2020-03-13'],
#  [151, 0, 0, 151, '2020-03-14'],
#  [162, 0, 0, 162, '2020-03-15'],
#  [200, 0, 1, 199, '2020-03-16'],
#  [321, 1, 2, 318, '2020-03-17'],
#  [372, 3, 2, 367, '2020-03-18'],
#  [621, 6, 2, 613, '2020-03-19'],
#  [793, 11, 2, 780, '2020-03-20'],
#  [1021, 15, 2, 1004, '2020-03-21'],
#  [1546, 25, 2, 1519, '2020-03-22'],
#  [1924, 34, 2, 1888, '2020-03-23'],
#  [2247, 46, 2, 2199, '2020-03-24'],
#  [2554, 59, 2, 2493, '2020-03-25'],
# ...

# %%
#data de verdade, pyhton oferece date time. biblioteca já instalada
#apresenta 3 objeto diferente
#1-tempo em horas, min, seg, micro
#2- data
#data e tempo

import datetime as dt

print(dt.time(12, 6, 21, 7), 'Hora:Minutos:segundo.microsegundo'

print(dt.date(2020, 4, 25), 'Ano-Mês-dia')    
print('---------------------------------')
print(dt.datetime(2020, 4, 25, 12, 6, 21, 7), 'Ano-Mês-dia  hora:minuto:segundo.microsegundo')
# Out:
#   Input In [44]
#     print(dt.date(2020, 4, 25), 'Ano-Mês-dia')
#     ^
# SyntaxError: invalid syntax

# %%
#delta de variação de tempo

natal = dt.date(2020, 12, 25)
reveillon = dt.date (2021, 1, 1)

print(reveillon - natal)
print((reveillon - natal).days)
print((reveillon - natal).seconds)
print((reveillon - natal).microseconds)
# Out:
# 7 days, 0:00:00
# 7
# 0
# 0

# %%
import csv
import datetime as dt

# %%
with open('brasil-covid.csv', 'w') as file:
    writer = csv.writer(file)
    writer.writerows(final_data)

# %%
for i in range(1, len(final_data)):
    
    final_data[i][DATA] = dt.datetime.strptime(str(final_data[i][DATA]), '%Y-%m-%d %H:%M:%S')

# %%
final_data
# Out:
# [[1, 0, 0, 1, '2020-02-26T00:00:00Z'],
#  [1, 0, 0, 1, datetime.datetime(2020, 2, 27, 0, 0)],
#  [1, 0, 0, 1, datetime.datetime(2020, 2, 28, 0, 0)],
#  [2, 0, 0, 2, datetime.datetime(2020, 2, 29, 0, 0)],
#  [2, 0, 0, 2, datetime.datetime(2020, 3, 1, 0, 0)],
#  [2, 0, 0, 2, datetime.datetime(2020, 3, 2, 0, 0)],
#  [2, 0, 0, 2, datetime.datetime(2020, 3, 3, 0, 0)],
#  [4, 0, 0, 4, datetime.datetime(2020, 3, 4, 0, 0)],
#  [4, 0, 0, 4, datetime.datetime(2020, 3, 5, 0, 0)],
#  [13, 0, 0, 13, datetime.datetime(2020, 3, 6, 0, 0)],
#  [13, 0, 0, 13, datetime.datetime(2020, 3, 7, 0, 0)],
#  [20, 0, 0, 20, datetime.datetime(2020, 3, 8, 0, 0)],
#  [25, 0, 0, 25, datetime.datetime(2020, 3, 9, 0, 0)],
#  [31, 0, 0, 31, datetime.datetime(2020, 3, 10, 0, 0)],
#  [38, 0, 0, 38, datetime.datetime(2020, 3, 11, 0, 0)],
#  [52, 0, 0, 52, datetime.datetime(2020, 3, 12, 0, 0)],
#  [151, 0, 0, 151, datetime.datetime(2020, 3, 13, 0, 0)],
#  [151, 0, 0, 151, datetime.datetime(2020, 3, 14, 0, 0)],
# ...

# %%
def get_datasets(y, labels):
    if type (y[0]) == list:
        datasets = []
        for i in range(len(y)):
            datasets.append({
                'label' : labels[i],
                'data': y[i]
            })
        return datasets
    else:
        return [
            { 'label': labels [0],
             'data': y
            
            }]

# %%
def set_title (title = ''):
    if title != '':
        display = 'true'
    else:
        display = 'false'
    return {
        'title': title,
        'display': display
    }

# %%
def create_chart(x, y, labels, kind= 'bar', title=''):
    datasets = get_datasets(y, labels)
    options = set_title (title)
    
    chart = {
        'type': kind,
        'data': {
            'labels':x,
        'datasets': datasets
        },
        'options': options
    }
    return chart

# %%
def get_api_chart(chart):
    url_base = 'https://quickchart.io/chart'
    resp = r.get(f'{url_base}?c={str(chart)}')
    return resp.content

# %%
from PIL import Image
from IPython.display import display


def save_image(path, content):
    with open (path, 'wb') as image:
        image.write(content)

# %%
#para mostrar as imagens aqui no nb
def display_image(path):
    img_pil = Image.open(path)
    display(img_pil)

# %%
#pegas os dados confirmados em x e os recuperados em y
y_data_1 = []
for obs in final_data[1::50]: #de10em10
    y_data_1.append(obs[CONFIRMADOS])


y_data_2 = []
for obs in final_data[1::50]: #de10em10
    y_data_2.append(obs[RECUPERADOS])
    

labels = ['Confirmados', 'Recuperados']

x= []

for obs in final_data[1::50]:
    x.append(obs[DATA].strftime('%d/%m/%Y'))
    
chart = create_chart(x, [y_data_1, y_data_2], labels, title='Gráfico Confirmados vs recuperados')
chart_content = get_api_chart(chart)
save_image('meu-primeiro-grafico.png', chart_content)
display_image('meu-primeiro-grafico.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1000x600 at 0x18D84DC0BB0>

# %%
from urllib.parse import quote

# %%
def get_api_qrcode(link):
    text = quote(link) #parsin do link para url
    url_base = 'https://quickchart.io/qr'
    resp = r.get(f'{url_base}?text={text}')
    return resp.content

# %%
url_base ='https://quickchart.io/chart'
link = f'{url_base}?c={str(chart)}'
save_image('qr-code.png', get_api_qrcode(link))
display_image('qr-code.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=150x150 at 0x18D84DC0A60>
